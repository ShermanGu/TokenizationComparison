# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = {
    "BPE": 18.527955881408168,
    "SentencePiece": 6.163352900935236,
    "WordPiece": 7.779238359913661
}
df = pd.DataFrame(list(results.items()), columns=["Tokenizer", "BLEU"])
df.plot(x="Tokenizer", y="BLEU", kind="bar")
plt.title("BLEU Score Comparison")
plt.ylabel("BLEU")
plt.show()
